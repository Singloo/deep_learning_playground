# %%
from fastai.vision import *
import os,sys

# %%
path = os.path.abspath('./models')

# %%
learn = load_learner(path)

# %%
imgPath = Path('./')
img = open_image(imgPath/'tests'/'002.jpg')
img
# Out:
# Image (3, 720, 1080)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
print(pred_class)
# Out:
# Bangs;Big_Nose;Eyeglasses;Male;No_Beard
